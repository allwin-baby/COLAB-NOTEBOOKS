# %%
from tensorflow.keras.models import Model
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img
import numpy as np
from glob import glob
import matplotlib.pyplot as plt

# %%
# re-size all the images to this
IMAGE_SIZE = [224, 224]

train_path = 'Datasets/train'
valid_path = 'Datasets/test'

# %%
resnet = ResNet50(input_shape=IMAGE_SIZE + [3], weights='imagenet', include_top=False)

# %%
for layer in resnet.layers:
    layer.trainable = False

# %%
folders = glob('Datasets/train/*')

# %%
x = Flatten()(resnet.output) #add

# %%
prediction = Dense(len(folders), activation='softmax')(x)

model = Model(inputs=resnet.input, outputs=prediction)

# %%
model.summary()

# %%
model.compile(
  loss='categorical_crossentropy',
  optimizer='adam',
  metrics=['accuracy']
)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
training_set = train_datagen.flow_from_directory('Datasets/train',
                                                 target_size = (224, 224),
                                                 batch_size = 32,
                                                 class_mode = 'categorical')

# %%
test_set = test_datagen.flow_from_directory('Datasets/test',
                                            target_size = (224, 224),
                                            batch_size = 32,
                                            class_mode = 'categorical')

# %%
r = model.fit_generator(
  training_set,
  validation_data=test_set,
  epochs=20,
  steps_per_epoch=len(training_set),
  validation_steps=len(test_set)
)

# %%
import matplotlib.pyplot as plt

# %%
from tensorflow.keras.models import load_model

#model.save('model_resnet50.h5')

# %%
y_pred = model.predict(test_set)

# %%
y_pred

# %%
import numpy as np
y_pred = np.argmax(y_pred, axis=1)

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image

# %%
#model=load_model('model_resnet50.h5')

# %%
img_data

# %%
img=image.load_img('image',target_size=(224,224))

# %%
x=image.img_to_array(img)
x

# %%
x=x/255

# %%
import numpy as np
x=np.expand_dims(x,axis=0)
img_data=preprocess_input(x)
img_data.shape

# %%
model.predict(img_data)

# %%
np.argmax(model.predict(img_data), axis=1)

# %% [markdown]
# KAGGLE

# %%
! pip install -q kaggle

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-54d8b602-d21d-49f9-a8fa-4cdd72859293" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-54d8b602-d21d-49f9-a8fa-4cdd72859293">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"allwin123321","key":"8e58f1190858ee4607ecb80861a4d991"}'}

# %%
! mkdir ~/.kaggle

# %%
! cp kaggle.json ~/.kaggle/

# %%
 # !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle competitions download -c cassava-disease
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.10 / client 1.5.4)
# Downloading train.zip to /content
#  99% 770M/777M [00:10<00:00, 77.3MB/s]
# 100% 777M/777M [00:10<00:00, 78.2MB/s]
# Downloading extraimages.zip to /content
#  99% 1.03G/1.04G [00:12<00:00, 77.5MB/s]
# 100% 1.04G/1.04G [00:12<00:00, 87.3MB/s]
# Downloading sample_submission_file.csv to /content
#   0% 0.00/83.8k [00:00<?, ?B/s]
# 100% 83.8k/83.8k [00:00<00:00, 12.3MB/s]
# Downloading random.txt to /content
#   0% 0.00/645k [00:00<?, ?B/s]
# 100% 645k/645k [00:00<00:00, 19.6MB/s]
# Downloading test.zip to /content
#  99% 508M/515M [00:08<00:00, 64.4MB/s]
# 100% 515M/515M [00:08<00:00, 66.4MB/s]

# %%
! mkdir dataset_init_file

# %%
! unzip /content/extraimages.zip -d dataset_init_file
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: dataset_init_file/extraimages/extra-image-10695.jpg
#   inflating: dataset_init_file/extraimages/extra-image-12082.jpg
#   inflating: dataset_init_file/extraimages/extra-image-15935.jpg
#   inflating: dataset_init_file/extraimages/extra-image-5819.jpg
#   inflating: dataset_init_file/extraimages/extra-image-4050.jpg
#   inflating: dataset_init_file/extraimages/extra-image-2421.jpg
#   inflating: dataset_init_file/extraimages/extra-image-15262.jpg
#   inflating: dataset_init_file/extraimages/extra-image-6647.jpg
#   inflating: dataset_init_file/extraimages/extra-image-9574.jpg
#   inflating: dataset_init_file/extraimages/extra-image-7559.jpg
#   inflating: dataset_init_file/extraimages/extra-image-1896.jpg
#   inflating: dataset_init_file/extraimages/extra-image-9212.jpg
#   inflating: dataset_init_file/extraimages/extra-image-15504.jpg
#   inflating: dataset_init_file/extraimages/extra-image-5428.jpg
#   inflating: dataset_init_file/extraimages/extra-image-2347.jpg
#   inflating: dataset_init_file/extraimages/extra-image-3059.jpg
#   inflating: dataset_init_file/extraimages/extra-image-13175.jpg
#   inflating: dataset_init_file/extraimages/extra-image-4736.jpg
#   inflating: dataset_init_file/extraimages/extra-image-884.jpg
#   inflating: dataset_init_file/extraimages/extra-image-15510.jpg
#   inflating: dataset_init_file/extraimages/extra-image-2353.jpg
#   inflating: dataset_init_file/extraimages/extra-image-648.jpg
#   inflating: dataset_init_file/extraimages/extra-image-13161.jpg
#   inflating: dataset_init_file/extraimages/extra-image-890.jpg
#   inflating: dataset_init_file/extraimages/extra-image-8118.jpg
#   inflating: dataset_init_file/extraimages/extra-image-1882.jpg
#   inflating: dataset_init_file/extraimages/extra-image-11776.jpg
#   inflating: dataset_init_file/extraimages/extra-image-6135.jpg
#   inflating: dataset_init_file/extraimages/extra-image-9206.jpg
#   inflating: dataset_init_file/extraimages/extra-image-6653.jpg
#   inflating: dataset_init_file/extraimages/extra-image-9560.jpg
#   inflating: dataset_init_file/extraimages/extra-image-11010.jpg
#   inflating: dataset_init_file/extraimages/extra-image-14168.jpg
#   inflating: dataset_init_file/extraimages/extra-image-13607.jpg
#   inflating: dataset_init_file/extraimages/extra-image-2435.jpg
#   inflating: dataset_init_file/extraimages/extra-image-12519.jpg
#   inflating: dataset_init_file/extraimages/extra-image-15276.jpg
#   inflating: dataset_init_file/extraimages/extra-image-9548.jpg
#   inflating: dataset_init_file/extraimages/extra-image-1114.jpg
#   inflating: dataset_init_file/extraimages/extra-image-11038.jpg
#   inflating: dataset_init_file/extraimages/extra-image-10326.jpg
#   inflating: dataset_init_file/extraimages/extra-image-8656.jpg
#   inflating: dataset_init_file/extraimages/extra-image-3703.jpg
#   inflating: dataset_init_file/extraimages/extra-image-12531.jpg
#   inflating: dataset_init_file/extraimages/extra-image-106.jpg
#   inflating: dataset_init_file/extraimages/extra-image-5372.jpg
#   inflating: dataset_init_file/extraimages/extra-image-5414.jpg
#   inflating: dataset_init_file/extraimages/extra-image-15538.jpg
#   inflating: dataset_init_file/extraimages/extra-image-660.jpg
#   inflating: dataset_init_file/extraimages/extra-image-3065.jpg
#   inflating: dataset_init_file/extraimages/extra-image-14626.jpg
#   inflating: dataset_init_file/extraimages/extra-image-8130.jpg
#   inflating: dataset_init_file/extraimages/extra-image-7203.jpg
#   inflating: dataset_init_file/extraimages/extra-image-11986.jpg
#   inflating: dataset_init_file/extraimages/extra-image-10440.jpg
#   inflating: dataset_init_file/extraimages/extra-image-1672.jpg
#   inflating: dataset_init_file/extraimages/extra-image-16031.jpg
#   inflating: dataset_init_file/extraimages/extra-image-8124.jpg
#   inflating: dataset_init_file/extraimages/extra-image-7217.jpg
#   inflating: dataset_init_file/extraimages/extra-image-10454.jpg
#   inflating: dataset_init_file/extraimages/extra-image-1666.jpg
#   inflating: dataset_init_file/extraimages/extra-image-16025.jpg
#   inflating: dataset_init_file/extraimages/extra-image-
jpg
#   inflating: dataset_init_file/extraimages/extra-image-14910.jpg
#   inflating: dataset_init_file/extraimages/extra-image-956.jpg
#   inflating: dataset_init_file/extraimages/extra-image-3835.jpg
#   inflating: dataset_init_file/extraimages/extra-image-13919.jpg
#   inflating: dataset_init_file/extraimages/extra-image-6795.jpg
#   inflating: dataset_init_file/extraimages/extra-image-8960.jpg
#   inflating: dataset_init_file/extraimages/extra-image-7104.jpg
#   inflating: dataset_init_file/extraimages/extra-image-8237.jpg
#   inflating: dataset_init_file/extraimages/extra-image-9129.jpg
#   inflating: dataset_init_file/extraimages/extra-image-1575.jpg
#   inflating: dataset_init_file/extraimages/extra-image-12150.jpg
#   inflating: dataset_init_file/extraimages/extra-image-567.jpg
#   inflating: dataset_init_file/extraimages/extra-image-14521.jpg
#   inflating: dataset_init_file/extraimages/extra-image-3362.jpg
#   inflating: dataset_init_file/extraimages/extra-image-3404.jpg
#   inflating: dataset_init_file/extraimages/extra-image-13528.jpg
#   inflating: dataset_init_file/extraimages/extra-image-14247.jpg
#   inflating: dataset_init_file/extraimages/extra-image-15159.jpg
#   inflating: dataset_init_file/extraimages/extra-image-5075.jpg
#   inflating: dataset_init_file/extraimages/extra-image-12636.jpg
#   inflating: dataset_init_file/extraimages/extra-image-201.jpg
#   inflating: dataset_init_file/extraimages/extra-image-1213.jpg
#   inflating: dataset_init_file/extraimages/extra-image-7662.jpg
#   inflating: dataset_init_file/extraimages/extra-image-8551.jpg
#   inflating: dataset_init_file/extraimages/extra-image-10021.jpg
#   inflating: dataset_init_file/extraimages/extra-image-1207.jpg
#   inflating: dataset_init_file/extraimages/extra-image-7676.jpg
#   inflating: dataset_init_file/extraimages/extra-image-8545.jpg
#   inflating: dataset_init_file/extraimages/extra-image-10035.jpg
#   inflating: dataset_init_file/extraimages/extra-image-9883.jpg
#   inflating: dataset_init_file/extraimages/extra-image-14253.jpg
#   inflating: dataset_init_file/extraimages/extra-image-5061.jpg
#   inflating: dataset_init_file/extraimages/extra-image-215.jpg
#   inflating: dataset_init_file/extraimages/extra-image-12622.jpg
#   inflating: dataset_init_file/extraimages/extra-image-2068.jpg
#   inflating: dataset_init_file/extraimages/extra-image-573.jpg
#   inflating: dataset_init_file/extraimages/extra-image-12144.jpg
#   inflating: dataset_init_file/extraimages/extra-image-14535.jpg
#   inflating: dataset_init_file/extraimages/extra-image-4419.jpg
#   inflating: dataset_init_file/extraimages/extra-image-3376.jpg
#   inflating: dataset_init_file/extraimages/extra-image-10753.jpg
#   inflating: dataset_init_file/extraimages/extra-image-7110.jpg
#   inflating: dataset_init_file/extraimages/extra-image-8223.jpg
#   inflating: dataset_init_file/extraimages/extra-image-2040.jpg
#   inflating: dataset_init_file/extraimages/extra-image-15603.jpg
#   inflating: dataset_init_file/extraimages/extra-image-7138.jpg
#   inflating: dataset_init_file/extraimages/extra-image-9115.jpg
#   inflating: dataset_init_file/extraimages/extra-image-6226.jpg
#   inflating: dataset_init_file/extraimages/extra-image-11465.jpg
#   inflating: dataset_init_file/extraimages/extra-image-7886.jpg
#   inflating: dataset_init_file/extraimages/extra-image-9673.jpg
#   inflating: dataset_init_file/extraimages/extra-image-6540.jpg
#   inflating: dataset_init_file/extraimages/extra-image-13514.jpg
#   inflating: dataset_init_file/extraimages/extra-image-3438.jpg
#   inflating: dataset_init_file/extraimages/extra-image-4357.jpg
#   inflating: dataset_init_file/extraimages/extra-image-15165.jpg
#   inflating: dataset_init_file/extraimages/extra-image-2726.jpg
#   inflating: dataset_init_file/extraimages/extra-image-4343.jpg
#   inflating: dataset_init_file/extraimages/extra-image-15171.jpg
#   inflating: dataset_init_file/extraimages/extra-image-229.jpg
#   inflating: dataset_init_file/extraimages/extra-image-2732.jpg
#   inflating: dataset_init_file/extraimages/extra-image-7892.jpg
#   inflating: dataset_init_file/extraimages/extra-image-6554.jpg
#   inflating: dataset_init_file/extraimages/extra-image-10009.jpg
#   inflating: dataset_init_file/extraimages/extra-image-9101.jpg
#   inflating: dataset_init_file/extraimages/extra-image-6232.jpg
#   inflating: dataset_init_file/extraimages/extra-image-11471.jpg
#   inflating: dataset_init_file/extraimages/extra-image-12178.jpg
#   inflating: dataset_init_file/extraimages/extra-image-2054.jpg
#   inflating: dataset_init_file/extraimages/extra-image-15617.jpg
#   inflating: dataset_init_file/extraimages/extra-image-4425.jpg
#   inflating: dataset_init_file/extraimages/extra-image-14509.jpg
#   inflating: dataset_init_file/extraimages/extra-image-13266.jpg
#   inflating: dataset_init_file/extraimages/extra-image-15824.jpg
#   inflating: dataset_init_file/extraimages/extra-image-5908.jpg
#   inflating: dataset_init_file/extraimages/extra-image-10784.jpg
#   inflating: dataset_init_file/extraimages/extra-image-9854.jpg
#   inflating: dataset_init_file/extraimages/extra-image-7879.jpg
#   inflating: dataset_init_file/extraimages/extra-image-14284.jpg
#   inflating: dataset_init_file/extraimages/extra-image-14290.jpg
#   inflating: dataset_init_file/extraimages/extra-image-2915.jpg
#   inflating: dataset_init_file/extraimages/extra-image-12839.jpg
#   inflating: dataset_init_file/extraimages/extra-image-8586.jpg
#   inflating: dataset_init_file/extraimages/extra-image-9698.jpg
#   inflating: dataset_init_file/extraimages/extra-image-10790.jpg
#   inflating: dataset_init_file/extraimages/extra-image-15830.jpg
#   inflating: dataset_init_file/extraimages/extra-image-13299.jpg
#   inflating: dataset_init_file/extraimages/extra-image-12187.jpg
#   inflating: dataset_init_file/extraimages/extra-image-10960.jpg
#   inflating: dataset_init_file/extraimages/extra-image-5934.jpg
#   inflating: dataset_init_file/extraimages/extra-image-15818.jpg
#   inflating: dataset_init_file/extraimages/extra-image-598.jpg
#   inflating: dataset_init_file/extraimages/extra-image-2083.jpg
#   inflating: dataset_init_file/extraimages/extra-image-4394.jpg
#   inflating: dataset_init_file/extraimages/extra-image-12811.jpg
#   inflating: dataset_init_file/extraimages/extra-image-9868.jpg
#   inflating: dataset_init_file/extraimages/extra-image-7689.jpg
#   inflating: dataset_init_file/extraimages/extra-image-6597.jpg
#   inflating: dataset_init_file/extraimages/extra-image-12805.jpg
#   inflating: dataset_init_file/extraimages/extra-image-4380.jpg
#   inflating: dataset_init_file/extraimages/extra-image-2929.jpg
#   inflating: dataset_init_file/extraimages/extra-image-5920.jpg
#   inflating: dataset_init_file/extraimages/extra-image-3389.jpg
#   inflating: dataset_init_file/extraimages/extra-image-2097.jpg
#   inflating: dataset_init_file/extraimages/extra-image-10974.jpg

# %%
pip install split-folders

# %%
import splitfolders
splitfolders.ratio("/content/train/train", output="/content/output", seed=1337, ratio=(.8, .1, .1), group_prefix=None) # default values

# %%
# !kaggle competitions download -c cassava-leaf-disease-classification
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.10 / client 1.5.4)
# Downloading 2216849948.jpg to /content
#   0% 0.00/141k [00:00<?, ?B/s]
# 100% 141k/141k [00:00<00:00, 22.3MB/s]
# Downloading ld_train12-1338.tfrec.zip to /content
#  98% 212M/216M [00:04<00:00, 52.3MB/s]
# 100% 216M/216M [00:04<00:00, 54.7MB/s]
# Downloading ld_train08-1338.tfrec.zip to /content
#  93% 201M/217M [00:04<00:00, 42.6MB/s]
# 100% 217M/217M [00:04<00:00, 45.7MB/s]
# Downloading ld_train14-1338.tfrec.zip to /content
#  98% 211M/215M [00:03<00:00, 76.0MB/s]
# 100% 215M/215M [00:03<00:00, 68.1MB/s]
# Downloading ld_train10-1338.tfrec.zip to /content
#  97% 210M/217M [00:02<00:00, 78.9MB/s]
# 100% 217M/217M [00:03<00:00, 75.2MB/s]
# Downloading ld_train05-1338.tfrec.zip to /content
#  94% 201M/214M [00:04<00:00, 37.9MB/s]
# 100% 214M/214M [00:04<00:00, 47.9MB/s]
# Downloading ld_train15-1327.tfrec.zip to /content
#  98% 210M/214M [00:05<00:00, 26.2MB/s]
# 100% 214M/214M [00:05<00:00, 40.8MB/s]
# Downloading ld_train09-1338.tfrec.zip to /content
#  97% 209M/216M [00:05<00:00, 24.5MB/s]
# 100% 216M/216M [00:05<00:00, 38.5MB/s]
# Downloading ld_train11-1338.tfrec.zip to /content
#  97% 212M/218M [00:04<00:00, 28.3MB/s]
# 100% 218M/218M [00:04<00:00, 47.2MB/s]
# Downloading ld_train03-1338.tfrec.zip to /content
#  98% 213M/217M [00:04<00:00, 48.9MB/s]
# 100% 217M/217M [00:04<00:00, 50.7MB/s]
# Downloading ld_train00-1338.tfrec.zip to /content
#  97% 210M/217M [00:04<00:00, 47.8MB/s]
# 100% 217M/217M [00:04<00:00, 55.0MB/s]
# Downloading ld_train07-1338.tfrec.zip to /content
#  95% 205M/216M [00:03<00:00, 76.3MB/s]
# 100% 216M/216M [00:03<00:00, 59.7MB/s]
# Downloading ld_train01-1338.tfrec.zip to /content
#  96% 206M/215M [00:04<00:00, 76.0MB/s]
# 100% 215M/215M [00:04<00:00, 51.9MB/s]
# Downloading ld_train13-1338.tfrec.zip to /content
# 100% 217M/217M [00:03<00:00, 67.6MB/s]
# 100% 217M/217M [00:03<00:00, 57.8MB/s]
# Downloading ld_train02-1338.tfrec.zip to /content
#  97% 209M/216M [00:03<00:00, 71.2MB/s]
# 100% 216M/216M [00:03<00:00, 67.4MB/s]
# Downloading ld_train04-1338.tfrec.zip to /content
#  91% 196M/216M [00:04<00:00, 33.6MB/s]
# 100% 216M/216M [00:05<00:00, 45.0MB/s]
# Downloading ld_train06-1338.tfrec.zip to /content
#  97% 210M/216M [00:04<00:00, 60.0MB/s]
# 100% 216M/216M [00:04<00:00, 52.4MB/s]
# Downloading ld_test00-1.tfrec to /content
#   0% 0.00/191k [00:00<?, ?B/s]
# 100% 191k/191k [00:00<00:00, 68.5MB/s]
# Downloading 1001723730.jpg to /content
#   0% 0.00/83.5k [00:00<?, ?B/s]
# 100% 83.5k/83.5k [00:00<00:00, 82.5MB/s]
# Downloading 1000201771.jpg to /content
#   0% 0.00/158k [00:00<?, ?B/s]
# 100% 158k/158k [00:00<00:00, 215MB/s]
# Downloading 1000910826.jpg to /content
#   0% 0.00/100k [00:00<?, ?B/s]
# 100% 100k/100k [00:00<00:00, 43.1MB/s]
# Downloading 1000015157.jpg to /content
#   0% 0.00/136k [00:00<?, ?B/s]
# 100% 136k/136k [00:00<00:00, 91.0MB/s]
# Downloading 1003888281.jpg to /content
#   0% 0.00/110k [00:00<?, ?B/s]
# 100% 110k/110k [00:00<00:00, 111MB/s]
# Downloading 1001320321.jpg to /content
#   0% 0.00/82.3k [00:00<?, ?B/s]
# 100% 82.3k/82.3k [00:00<00:00, 77.2MB/s]
# Downloading 1001749118.jpg to /content
#   0% 0.00/135k [00:00<?, ?B/s]
# 100% 135k/135k [00:00<00:00, 39.6MB/s]
# Downloading 1003218714.jpg to /content
#   0% 0.00/127k [00:00<?, ?B/s]
# 100% 127k/127k [00:00<00:00, 75.2MB/s]
# Downloading 1002088496.jpg to /content
#   0% 0.00/131k [00:00<?, ?B/s]
# 100% 131k/131k [00:00<00:00, 40.6MB/s]
# Downloading 1003298598.jpg to /content
#   0% 0.00/142k [00:00<?, ?B/s]
# 100% 142k/142k [00:00<00:00, 41.8MB/s]
# Downloading 1000837476.jpg to /content
#   0% 0.00/104k [00:00<?, ?B/s]
# 100% 104k/104k [00:00<00:00, 89.1MB/s]
# Downloading 100204014.jpg to /content
#   0% 0.00/170k [00:00<?, ?B/s]
# 100% 170k/170k [00:00<00:00, 129MB/s]
# Downloading 1002394761.jpg to /content
#   0% 0.00/101k [00:00<?, ?B/s]
# 100% 101k/101k [00:00<00:00, 90.8MB/s]
# Downloading 1001742395.jpg to /content
#   0% 0.00/99.7k [00:00<?, ?B/s]
# 100% 99.7k/99.7k [00:00<00:00, 33.3MB/s]
# Downloading 1003442061.jpg to /content
#   0% 0.00/101k [00:00<?, ?B/s]
# 100% 101k/101k [00:00<00:00, 14.0MB/s]
# Downloading 1000812911.jpg to /content
#   0% 0.00/79.1k [00:00<?, ?B/s]
# 100% 79.1k/79.1k [00:00<00:00, 73.7MB/s]
# Downloading 100042118.jpg to /content
#   0% 0.00/72.8k [00:00<?, ?B/s]
# 100% 72.8k/72.8k [00:00<00:00, 25.2MB/s]
# Downloading 1003987001.jpg to /content
#   0% 0.00/101k [00:00<?, ?B/s]
# 100% 101k/101k [00:00<00:00, 73.5MB/s]
# Downloading 1002255315.jpg to /content
#   0% 0.00/150k [00:00<?, ?B/s]
# 100% 150k/150k [00:00<00:00, 45.8MB/s]
# Downloading 1000723321.jpg to /content
#   0% 0.00/119k [00:00<?, ?B/s]
# 100% 119k/119k [00:00<00:00, 69.8MB/s]
# Downloading label_num_to_disease_map.json to /content
#   0% 0.00/172 [00:00<?, ?B/s]
# 100% 172/172 [00:00<00:00, 151kB/s]
# Downloading sample_submission.csv to /content
#   0% 0.00/32.0 [00:00<?, ?B/s]
# 100% 32.0/32.0 [00:00<00:00, 79.4kB/s]
# Downloading train.csv to /content
#   0% 0.00/350k [00:00<?, ?B/s]
# 100% 350k/350k [00:00<00:00, 46.4MB/s]

# %%
import pandas as pd
csv = pf.read.csv()
# Out:
#   File "<ipython-input-16-97df4fce3c68>", line 2
#     data = “,”.split(line)
#            ^
# SyntaxError: invalid character in identifier

# %%
# Out:
#          image_id  label
# 0  1000015157.jpg      0
